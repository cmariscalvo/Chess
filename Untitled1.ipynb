# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2
import os
inicio = plt.imread('inicio.png')


plt.imshow(rey)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-d8731a55e9ad> in <module>
#       3 import cv2
#       4 import os
# ----> 5 inicio = plt.imread('inicio.png')
#       6
#       7
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in imread(fname, format)
#    2244 @_copy_docstring_and_deprecators(matplotlib.image.imread)
#    2245 def imread(fname, format=None):
# -> 2246     return matplotlib.image.imread(fname, format)
#    2247
#    2248
#
# ~\anaconda3\lib\site-packages\matplotlib\image.py in imread(fname, format)
#    1488                     response = io.BytesIO(response.read())
#    1489                 return imread(response, format=ext)
# -> 1490     with img_open(fname) as image:
#    1491         return (_pil_png_to_float_array(image)
#    1492                 if isinstance(image, PIL.PngImagePlugin.PngImageFile) else
#
# ...

# %%
cd
# Out:
# C:\Users\Christian Mariscal

# %%
inicio = plt.imread('inicio.png')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-25cf4e8b4203> in <module>
# ----> 1 inicio = plt.imread('inicio.png')
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in imread(fname, format)
#    2244 @_copy_docstring_and_deprecators(matplotlib.image.imread)
#    2245 def imread(fname, format=None):
# -> 2246     return matplotlib.image.imread(fname, format)
#    2247
#    2248
#
# ~\anaconda3\lib\site-packages\matplotlib\image.py in imread(fname, format)
#    1488                     response = io.BytesIO(response.read())
#    1489                 return imread(response, format=ext)
# -> 1490     with img_open(fname) as image:
#    1491         return (_pil_png_to_float_array(image)
#    1492                 if isinstance(image, PIL.PngImagePlugin.PngImageFile) else
#
# ~\anaconda3\lib\site-packages\PIL\ImageFile.py in __init__(self, fp, filename)
# ...

# %%
cd
# Out:
# C:\Users\Christian Mariscal

# %%
cd Desktop\ajedrez
# Out:
# C:\Users\Christian Mariscal\Desktop\ajedrez

# %%
inicio = plt.imread('inicio.png')

# %%
plt.imshow(inicio)

# %%
inicio = plt.imread('inicio.png')
os.chdir('C:\\Users\\Christian Mariscal\\Desktop\\ajedrez\\FIGURAS')

rey = plt.imread('rey.png')
sift = cv2.xfeatures2d.SIFT_create()
kp1,des1 = sift.detectAndCompute(inicio,None)
kp2,des2 = sift.detectAndCompute(rey,None)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-9-8680b3c98291> in <module>
#       3
#       4 rey = plt.imread('rey.png')
# ----> 5 sift = cv2.xfeatures2d.SIFT_create()
#       6 kp1,des1 = sift.detectAndCompute(inicio,None)
#       7 kp2,des2 = sift.detectAndCompute(rey,None)
#
# error: OpenCV(4.0.1) C:\ci\opencv-suite_1573470242804\work\opencv_contrib-4.0.1\modules\xfeatures2d\src\sift.cpp:1207: error: (-213:The function/feature is not implemented) This algorithm is patented and is excluded in this configuration; Set OPENCV_ENABLE_NONFREE CMake option and rebuild the library in function 'cv::xfeatures2d::SIFT::create'
